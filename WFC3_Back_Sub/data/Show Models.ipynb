# %%
import matplotlib.pyplot as plt
import u
from astropy.io import fits
plt.rcParams["figure.figsize"] = (20,7)

# %%
d0 = fits.open("G102_Zodi_CLN8_V7b_clean.fits")[1].data
d1 = fits.open("G102_HeI_clean.fits")[1].data
d2 = fits.open("G102_Scatter_clean.fits")[1].data

u.show_data([d0,d1,d2])
# Out:
# (3, 1014, 1014)
# 3 subplots

# %%
d0 = fits.open("G141_Zodi_CLN8_V7_clean.fits")[1].data
d1 = fits.open("G141_HeI_clean.fits")[1].data
d2 = fits.open("G141_Scatter_clean.fits")[1].data

u.show_data([d0,d1,d2])
# Out:
# (3, 1014, 1014)
# 3 subplots
